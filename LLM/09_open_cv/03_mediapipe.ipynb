# %% [markdown]
# # Mediapipe

# %%
# !pip install opencv-python mediapipe
# Out:
# Requirement already satisfied: opencv-python in c:\users\ljh10\appdata\roaming\python\python39\site-packages (4.11.0.86)
# Collecting mediapipe
#   Downloading mediapipe-0.10.21-cp39-cp39-win_amd64.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\ljh10\anaconda3\envs\vectordb_env\lib\site-packages (from opencv-python) (1.26.4)
# Collecting absl-py (from mediapipe)
#   Downloading absl_py-2.2.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\ljh10\anaconda3\envs\vectordb_env\lib\site-packages (from mediapipe) (25.1.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\ljh10\anaconda3\envs\vectordb_env\lib\site-packages (from mediapipe) (25.2.10)
# Collecting jax (from mediapipe)
#   Downloading jax-0.4.30-py3-none-any.whl.metadata (22 kB)
# Collecting jaxlib (from mediapipe)
#   Downloading jaxlib-0.4.30-cp39-cp39-win_amd64.whl.metadata (1.1 kB)
# Collecting matplotlib (from mediapipe)
#   Downloading matplotlib-3.9.4-cp39-cp39-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: opencv-contrib-python in c:\users\ljh10\anaconda3\envs\vectordb_env\lib\site-packages (from mediapipe) (4.11.0.86)
# Collecting protobuf<5,>=4.25.3 (from mediapipe)
#   Downloading protobuf-4.25.6-cp39-cp39-win_amd64.whl.metadata (541 bytes)
# Collecting sounddevice>=0.4.4 (from mediapipe)
#   Downloading sounddevice-0.5.1-py3-none-win_amd64.whl.metadata (1.4 kB)
# Collecting sentencepiece (from mediapipe)
#   Downloading sentencepiece-0.2.0-cp39-cp39-win_amd64.whl.metadata (8.3 kB)
# Collecting CFFI>=1.0 (from sounddevice>=0.4.4->mediapipe)
#   Downloading cffi-1.17.1-cp39-cp39-win_amd64.whl.metadata (1.6 kB)
# Collecting ml-dtypes>=0.2.0 (from jax->mediapipe)
#   Downloading ml_dtypes-0.5.1-cp39-cp39-win_amd64.whl.metadata (22 kB)
# Requirement already satisfied: opt-einsum in c:\users\ljh10\anaconda3\envs\vectordb_env\lib\site-packages (from jax->mediapipe) (3.3.0)
# Requirement already satisfied: scipy>=1.9 in c:\users\ljh10\anaconda3\envs\vectordb_env\lib\site-packages (from jax->mediapipe) (1.13.1)
# Requirement already satisfied: importlib-metadata>=4.6 in c:\users\ljh10\anaconda3\envs\vectordb_env\lib\site-packages (from jax->mediapipe) (8.5.0)
# Collecting contourpy>=1.0.1 (from matplotlib->mediapipe)
#   Downloading contourpy-1.3.0-cp39-cp39-win_amd64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib->mediapipe)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ljh10\anaconda3\envs\vectordb_env\lib\site-packages (from matplotlib->mediapipe) (4.56.0)
# Collecting kiwisolver>=1.3.1 (from matplotlib->mediapipe)
#   Downloading kiwisolver-1.4.7-cp39-cp39-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\ljh10\anaconda3\envs\vectordb_env\lib\site-packages (from matplotlib->mediapipe) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\ljh10\anaconda3\envs\vectordb_env\lib\site-packages (from matplotlib->mediapipe) (11.1.0)
# Collecting pyparsing>=2.3.1 (from matplotlib->mediapipe)
#   Downloading pyparsing-3.2.2-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ljh10\anaconda3\envs\vectordb_env\lib\site-packages (from matplotlib->mediapipe) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\ljh10\anaconda3\envs\vectordb_env\lib\site-packages (from matplotlib->mediapipe) (6.5.2)
# Collecting pycparser (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe)
#   Using cached pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# Requirement already satisfied: zipp>=3.20 in c:\users\ljh10\anaconda3\envs\vectordb_env\lib\site-packages (from importlib-metadata>=4.6->jax->mediapipe) (3.21.0)
# Requirement already satisfied: six>=1.5 in c:\users\ljh10\anaconda3\envs\vectordb_env\lib\site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.17.0)
# Downloading mediapipe-0.10.21-cp39-cp39-win_amd64.whl (50.9 MB)
#    ---------------------------------------- 0.0/50.9 MB ? eta -:--:--
#    - -------------------------------------- 1.6/50.9 MB 8.4 MB/s eta 0:00:06
#    --- ------------------------------------ 3.9/50.9 MB 9.8 MB/s eta 0:00:05
#    ----- ---------------------------------- 6.6/50.9 MB 10.6 MB/s eta 0:00:05
#    ------ --------------------------------- 8.9/50.9 MB 10.9 MB/s eta 0:00:04
#    -------- ------------------------------- 11.3/50.9 MB 11.0 MB/s eta 0:00:04
#    ---------- ----------------------------- 13.6/50.9 MB 11.3 MB/s eta 0:00:04
#    ------------ --------------------------- 16.3/50.9 MB 11.2 MB/s eta 0:00:04
#    -------------- ------------------------- 18.6/50.9 MB 11.3 MB/s eta 0:00:03
#    ---------------- ----------------------- 21.2/50.9 MB 11.4 MB/s eta 0:00:03
#    ------------------ --------------------- 23.9/50.9 MB 11.4 MB/s eta 0:00:03
#    -------------------- ------------------- 26.2/50.9 MB 11.5 MB/s eta 0:00:03
#    ---------------------- ----------------- 28.8/50.9 MB 11.5 MB/s eta 0:00:02
#    ----------------------- ---------------- 30.4/50.9 MB 11.5 MB/s eta 0:00:02
#    ------------------------- -------------- 32.0/50.9 MB 11.0 MB/s eta 0:00:02
#    --------------------------- ------------ 34.6/50.9 MB 11.0 MB/s eta 0:00:02
#    ---------------------------- ----------- 36.2/50.9 MB 10.7 MB/s eta 0:00:02
#    ------------------------------ --------- 38.8/50.9 MB 10.8 MB/s eta 0:00:02
#    -------------------------------- ------- 41.2/50.9 MB 10.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 43.5/50.9 MB 10.9 MB/s eta 0:00:01
#    ------------------------------------ --- 45.9/50.9 MB 10.9 MB/s eta 0:00:01
#    -------------------------------------- - 48.5/50.9 MB 11.0 MB/s eta 0:00:01
#    ---------------------------------------  50.9/50.9 MB 11.0 MB/s eta 0:00:01
#    ---------------------------------------- 50.9/50.9 MB 10.8 MB/s eta 0:00:00
# Downloading protobuf-4.25.6-cp39-cp39-win_amd64.whl (413 kB)
# Downloading sounddevice-0.5.1-py3-none-win_amd64.whl (363 kB)
# Downloading absl_py-2.2.0-py3-none-any.whl (276 kB)
# Downloading jax-0.4.30-py3-none-any.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 2.0/2.0 MB 12.4 MB/s eta 0:00:00
# Downloading jaxlib-0.4.30-cp39-cp39-win_amd64.whl (51.9 MB)
#    ---------------------------------------- 0.0/51.9 MB ? eta -:--:--
#    - -------------------------------------- 2.4/51.9 MB 11.2 MB/s eta 0:00:05
#    --- ------------------------------------ 4.7/51.9 MB 11.4 MB/s eta 0:00:05
#    ----- ---------------------------------- 7.3/51.9 MB 11.6 MB/s eta 0:00:04
#    ------- -------------------------------- 10.0/51.9 MB 11.7 MB/s eta 0:00:04
#    --------- ------------------------------ 12.3/51.9 MB 11.5 MB/s eta 0:00:04
#    ----------- ---------------------------- 14.9/51.9 MB 11.6 MB/s eta 0:00:04
#    ------------- -------------------------- 17.6/51.9 MB 11.7 MB/s eta 0:00:03
#    ------------- -------------------------- 17.8/51.9 MB 11.6 MB/s eta 0:00:03
#    --------------- ------------------------ 19.9/51.9 MB 10.3 MB/s eta 0:00:04
#    ----------------- ---------------------- 22.3/51.9 MB 10.5 MB/s eta 0:00:03
#    ------------------- -------------------- 24.9/51.9 MB 10.6 MB/s eta 0:00:03
#    -------------------- ------------------- 27.3/51.9 MB 10.7 MB/s eta 0:00:03
#    ---------------------- ----------------- 29.4/51.9 MB 10.6 MB/s eta 0:00:03
#    ------------------------ --------------- 31.7/51.9 MB 10.8 MB/s eta 0:00:02
#    -------------------------- ------------- 34.3/51.9 MB 10.8 MB/s eta 0:00:02
#    ---------------------------- ----------- 36.7/51.9 MB 10.9 MB/s eta 0:00:02
#    ------------------------------ --------- 39.3/51.9 MB 11.0 MB/s eta 0:00:02
#    -------------------------------- ------- 41.7/51.9 MB 11.0 MB/s eta 0:00:01
#    --------------------------------- ------ 44.0/51.9 MB 11.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 46.4/51.9 MB 11.1 MB/s eta 0:00:01
#    ------------------------------------- -- 49.0/51.9 MB 11.1 MB/s eta 0:00:01
#    ---------------------------------------  51.4/51.9 MB 11.1 MB/s eta 0:00:01
#    ---------------------------------------- 51.9/51.9 MB 11.0 MB/s eta 0:00:00
# Downloading matplotlib-3.9.4-cp39-cp39-win_amd64.whl (7.8 MB)
#    ---------------------------------------- 0.0/7.8 MB ? eta -:--:--
#    ------------ --------------------------- 2.4/7.8 MB 12.2 MB/s eta 0:00:01
#    ------------------------- -------------- 5.0/7.8 MB 12.1 MB/s eta 0:00:01
#    -------------------------- ------------- 5.2/7.8 MB 12.3 MB/s eta 0:00:01
#    -------------------------------------- - 7.6/7.8 MB 9.0 MB/s eta 0:00:01
#    ---------------------------------------- 7.8/7.8 MB 8.8 MB/s eta 0:00:00
# Downloading sentencepiece-0.2.0-cp39-cp39-win_amd64.whl (991 kB)
#    ---------------------------------------- 0.0/991.5 kB ? eta -:--:--
#    --------------------------------------- 991.5/991.5 kB 11.8 MB/s eta 0:00:00
# Downloading cffi-1.17.1-cp39-cp39-win_amd64.whl (181 kB)
# Downloading contourpy-1.3.0-cp39-cp39-win_amd64.whl (211 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading kiwisolver-1.4.7-cp39-cp39-win_amd64.whl (55 kB)
# Downloading ml_dtypes-0.5.1-cp39-cp39-win_amd64.whl (209 kB)
# Downloading pyparsing-3.2.2-py3-none-any.whl (111 kB)
# Using cached pycparser-2.22-py3-none-any.whl (117 kB)
# Installing collected packages: sentencepiece, pyparsing, pycparser, protobuf, ml-dtypes, kiwisolver, cycler, contourpy, absl-py, matplotlib, jaxlib, CFFI, sounddevice, jax, mediapipe
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.2
#     Uninstalling protobuf-3.20.2:
#       Successfully uninstalled protobuf-3.20.2
# Successfully installed CFFI-1.17.1 absl-py-2.2.0 contourpy-1.3.0 cycler-0.12.1 jax-0.4.30 jaxlib-0.4.30 kiwisolver-1.4.7 matplotlib-3.9.4 mediapipe-0.10.21 ml-dtypes-0.5.1 protobuf-4.25.6 pycparser-2.22 pyparsing-3.2.2 sentencepiece-0.2.0 sounddevice-0.5.1
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\ljh10\anaconda3\envs\vectordb_env\Lib\site-packages\google\~rotobuf'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opentelemetry-proto 1.30.0 requires protobuf<6.0,>=5.0, but you have protobuf 4.25.6 which is incompatible.
# paddlepaddle 2.6.2 requires protobuf<=3.20.2,>=3.1.0; platform_system == "Windows", but you have protobuf 4.25.6 which is incompatible.

# %%
import cv2
import mediapipe as mp

mp_face_detector = mp.solutions.face_detection
mp_drawing = mp.solutions. drawing_utils

face_detector = mp_face_detector.FaceDetection(model_selection=0, min_detection_confidence=0.5)

# %%
cap = cv2.VideoCapture(0)

while cap.isOpened():
    ret, frame = cap.read()

    img_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    results = face_detector.process(img_rgb)

    # print(results.detections)
    
    if results.detections:
        for detection in results.detections:
            mp_drawing.draw_detection(frame, detection)

    cv2.imshow('Face_Detection', frame)
    
    if cv2.waitKey(1) & 0xFF == 27:
        break
    
cap.release()
cv2.destoryAllWindows()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 22
#      19         break
#      21 cap.release()
# ---> 22 cv2.destoryAllWindows()
#
# AttributeError: module 'cv2' has no attribute 'destoryAllWindows'
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ### 2. 얼굴 인식 모자이크

# %%
cap = cv2.VideoCapture(0)

while cap.isOpened():
    ret, frame = cap.read()

    img_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    img_h, img_w , _ = img_rgb.shape
    
    
    results = face_detector.process(img_rgb)

    if results.detections:
        for detection in results.detections:
            bbox = detection.location_data.relative_bounding_box
            
            x1 = int(max(bbox.xmin,0) * img_w)
            y1 = int(max(bbox.ymin,0) * img_h)
            width = int(bbox.width * img_w)
            height = int(bbox.height * img_h)
            x2 = min(x1 + width, img_w)
            y2 = min(y1 + height, img_h)
            
            face = img_rgb[y1:y2, x1:x2]
            face = cv2.resize(face, (10,10), interpolation=cv2.INTER_LINEAR)
            face = cv2.resize(face, (x2-x1, y2-y1), interpolation=cv2.INTER_LINEAR)

            img_rgb[y1:y2, x1:x2] = face
    
    img_rgb = cv2.cvtColor(img_rgb,cv2.COLOR_RGB2BGR)
    cv2.imshow('Face Detection', img_rgb)
    
    cv2.imshow('Face_Detection', frame)
    
    if cv2.waitKey(1) & 0xFF == 27:
        break
    
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 38
#      35         break
#      37 cap.release()
# ---> 38 cv2.destoryAllWindows()
#
# AttributeError: module 'cv2' has no attribute 'destoryAllWindows'
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ### 3. FaceMesh

# %%
import cv2
import mediapipe as mp
import numpy as np

# 얼굴 인식 및 얼굴 메쉬 솔루션 초기화
mp_drawing = mp.solutions.drawing_utils
mp_drawing_styles = mp.solutions.drawing_styles
mp_face_mesh = mp.solutions.face_mesh

# %%
cap = cv2.VideoCapture(0)

with mp_face_mesh.FaceMesh(
    max_num_faces=1,
    refine_landmarks=True,
    min_detection_confidence=0.5,
    min_tracking_confidence=0.5    
) as face_mesh:
    
    while cap.isOpened():
        ret, frame = cap.read()

        if not ret:
            break
        
        frame = cv2.flip(frame, 1)
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

        image.flags.writeable = False
        results = face_mesh.process(image)
        image.flags.writeable = True
        
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        if results.multi_face_landmarks:
            for face_landmark in results.multi_face_landmarks:
                
                # 얼굴 3d 구조 시각화(테슬레이션)
                mp_drawing.draw_landmarks(
                    image = image,
                    landmark_list=face_landmark,
                    connections=mp_face_mesh.FACEMESH_TESSELATION,  # 얼굴에 선으로 연결줌
                    landmark_drawing_spec=None,
                    connection_drawing_spec=mp_drawing_styles.get_default_face_mesh_tesselation_style()
                )

                # 얼굴 윤곽선 주요 특징 강조 (윤곽선, 눈썹, 눈, 입술)
                mp_drawing.draw_landmarks(
                    image=image,
                    landmark_list=face_landmark,
                    connections=mp_face_mesh.FACEMESH_CONTOURS,   #얼굴의 주요 특징 도출
                    landmark_drawing_spec=None,
                    connection_drawing_spec=mp_drawing_styles.get_default_face_mesh_contours_style()
                )
                
                # 눈의 형태와 위치 강조
                mp_drawing.draw_landmarks(
                    image=image,
                    landmark_list=face_landmark,
                    connections=mp_face_mesh.FACEMESH_IRISES,
                    landmark_drawing_spec=None,
                    connection_drawing_spec=mp_drawing_styles.get_default_face_mesh_iris_connections_style()
                )
                
        cv2.imshow('Face Mesh', image)
        
        if cv2.waitKey(1) & 0xFF == 27:
            break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ### 4. 필터 씌우기

# %%
import cv2
import mediapipe as mp
import numpy as np

# 얼굴 인식 및 얼굴 메쉬 솔루션 초기화
mp_draw = mp.solutions.drawing_utils
mp_face_mesh = mp.solutions.face_mesh

face_mesh = mp_face_mesh.FaceMesh()

# %%
mask_img = cv2.imread('mini.png', cv2.IMREAD_UNCHANGED)

# %%
# 얼굴 위에 오버레이 이미지를 합성하는 함수
def face_overlay(background_img, overlay_img,x,y,overlay_size=None):
    try:
        bg_img = background_img.copy()

        if bg_img.shape[2] == 3:
            bg_img = cv2.cvtColor(bg_img, cv2.COLOR_BGR2RGB)
        
        if overlay_size is not None:
            overlay_img = cv2.resize(overlay_img.copy(), overlay_size)

        b,g,r,a = cv2.split(overlay_img)
        mask = cv2.medianBlur(a,5)
        
        h,w,_ = overlay_img.shape
        roi = bg_img[int(y- h/2):int(y+ h/2), int(x-w/2):int(x+w/2)]
        img_bg1=cv2.bitwise_and(roi,roi,mask=cv2.bitwise_not(mask))
        img_bg2=cv2.bitwise_and(overlay_img.copy(), overlay_img.copy(), mask=mask)
        bg_img[int(y- h/2):int(y+ h/2), int(x-w/2):int(x+w/2)] = cv2.add(img_bg1, img_bg2)

        bg_img = cv2.cvtColor(bg_img, cv2.COLOR_BGR2RGB)
        return bg_img
        
    except:
        return background_img

# %%
cap = cv2.VideoCapture(0)

while True:

    ret, img = cap.read()

    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    result = face_mesh.process(img_rgb)
    img_h, img_w, img_c = img.shape

    if result.multi_face_landmarks:
        for face_landmark in result.multi_face_landmarks:
            xy_point = []

            for c, lm in enumerate(face_landmark.landmark):
                xy_point.append([lm.x, lm.y])
                img = cv2.circle(img, (int(lm.x * img_w), int(lm.y * img_h)), 1, (255, 0, 0), 2)

            top_left = np.min(xy_point, axis=0)
            bottom_right = np.max(xy_point, axis=0)

            mean_xy = np.mean(xy_point, axis=0)
            img = cv2.circle(img, (int(mean_xy[0] * img_w), int(mean_xy[1] * img_h)), 4, (255, 0, 0), 3)
            
            face_width = int(bottom_right[0] * img_w) - int(top_left[0] * img_w)
            face_height = int(bottom_right[1] * img_h) - int(top_left[1] * img_h)

            if face_width > 0 and face_height > 0:
                face_result = face_overlay(img, mask_img, int(mean_xy[0] * img_w), int(mean_xy[1] * img_h), overlay_size=(face_width, face_height))

    else:
        face_result = img

    cv2.imshow('mini mouse', face_result)

    if cv2.waitKey(1) == ord('q'):
        break


cap.release()
cv2.destroyAllWindows()
